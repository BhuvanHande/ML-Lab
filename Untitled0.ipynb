# %% [markdown]
# <a href="https://colab.research.google.com/github/BhuvanHande/ML-Lab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2
a=int(input("Enter a number : \n"))
if a>0:
  print("Number is Positive")
elif a==0:
  print("Neither positive nor negative")
else:
  print("the number is negative")
# Out:
# Enter a number :
# 7
# Number is Positive

# %%
#4
m=int(input("give the dividend:\n"))
n=int(input("give the divisor:\n"))
res=m//n
rem=m%n
print(f"the quotient is {res}")
print(f"remainder is {rem}")
# Out:
# give the dividend:
# 5
# give the divisor:
# 2
# the quotient is 2
# remainder is 1

# %%
#5
start=int(input("Enter the starting range: \n"))
end=int(input("Enter the ending range: \n"))

for i in range(start,end+1):
  if i%2 == 0:
    continue
  else:
    print(i)
# Out:
# Enter the starting range:
# 2
# Enter the ending range:
# 15
# 3
# 5
# 7
# 9
# 11
# 13
# 15

# %%
#6
sum1=0
num=456
while num > 0:
  digit=num%10
  # print(digit)
  sum+=digit

  num//=10
  print(sum)
# Out:
# 6
# 11
# 15

# %%
#7
num=int(input("Enter a number: "))
for i in range(2,num+1):
  if num%i==0:
    print(i)
    break
# Out:
# Enter a number: 6
# 2

# %%
#8
n=int(input("Enter a number\n"))
res=int(n)+int(n*2)+int(n*3)
print(res)
# Out:
# Enter a number
# 4
# 24

# %%
numbers = [10, 20, 30, 40, 50]

total = sum(numbers)
average = total / len(numbers)

print("Average =", average)
# Out:
# Average = 30.0

# %%
import kagglehub
import pandas as pd
import os
path = kagglehub.dataset_download("yasserh/titanic-dataset")
print("Path to dataset files:", path)

print(os.listdir(path))
# Out:
# Using Colab cache for faster access to the 'titanic-dataset' dataset.
# Path to dataset files: /kaggle/input/titanic-dataset
# ['Titanic-Dataset.csv']

# %%
df = pd.read_csv(os.path.join(path, "Titanic-Dataset.csv"))

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Total no. of passengers" , len(df))
# Average age of survivors
print("\nAverage age of survivors:")
print(df[df["Survived"] == 1]["Age"].mean())

# Average age of non survivors

print("\nAverage age of non survivors:")
print(df[df["Survived"] == 0]["Age"].mean())
print(df.groupby("Survived")["Fare"].mean())

print("\nAverage fare for each passenger class:")
print(df.groupby("Pclass")["Fare"].mean())
# Out:
# Total no. of passengers 891
#
# Average age of survivors:
# 28.343689655172415
#
# Average age of non survivors:
# 30.62617924528302
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64
#
# Average fare for each passenger class:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64
