# %% [markdown]
# <a href="https://colab.research.google.com/github/BhuvanHande/ML-Lab/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#
x = [0, 2, 2, 3, 3, 5, 5, 6, 6, 8, 8, 9, 9, 11, 11, 12, 12, 14, 14, 15, 15, 17, 17, 18, 18, 20, 20, 21, 21, 23, 23, 24, 24, 26, 26, 0, 0]

y = [0, 0, 4, 4, 0, 0, 5, 5, 0, 0, 4, 4, 0, 0, 5, 5, 0, 0, 7, 7, 0, 0, 4, 4, 0, 0, 8, 8, 0, 0, 4, 4, 0, 0, -2, -2, 0]

plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("line plot")
plt.show()

# %%
from sklearn.datasets import load_iris
iris= load_iris(as_frame=True)
df=iris.frame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
plt.scatter(df['sepal length (cm)'],
            df['petal length (cm)'])
plt.xlabel("sepal length")
plt.ylabel("petal width")
plt.title("scatter plot")
plt.show()
